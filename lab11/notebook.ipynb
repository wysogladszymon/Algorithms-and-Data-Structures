# %%
import numpy as np
import matplotlib.pyplot as plt
from main import main
import biometrics

# %%
main()
# Out:
# Processing  Retina_graph_easy_3.png ...
# Saved!
# Processing  Retina_graph_easy_2.png ...
# Saved!
# Processing  Retina_graph_easy_1.png ...
# Saved!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 main()
#
# File ~/myDocs/uczelnia/ASD/lab11/main.py:35, in main()
#      32 graph1_input = input_data[i][1]
#      33 graph2_input = input_data[j][1]
# ---> 35 graph1, graph2 = biometric_graph_registration(graph1_input, graph2_input, Ni=50, eps=10)
#      37 plt.figure()
#      38 graph1.plot_graph(v_color='red', e_color='green')
#
# TypeError: cannot unpack non-iterable NoneType object
